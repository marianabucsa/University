# %%
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=s^2-2*s
eq=solve(f(s)==0,s)
x1=eq[0].rhs()
x2=eq[1].rhs()
show(diff(f,s)(x1))
show(diff(f,s)(x2))
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3), headaxislength=3, headlength=4, color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq,x,[0,-0.5],step=0.01, end_points=[-5,5],output='plot', color='yellow')
g2=desolve_rk4(deq,x,[0,1],step=0.01, end_points=[-5,5],output='plot', color='blue')
g3=desolve_rk4(deq,x,[0,3],step=0.01, end_points=[-5,5],output='plot', color='green')
g4=desolve_rk4(deq,x,[0,2],step=0.01, end_points=[-5,5],output='plot', color='purple')
g5=desolve_rk4(deq,x,[0,0],step=0.01, end_points=[-5,5],output='plot', color='brown')
g=sf+g1+g2+g3+g4+g5
g.show(ymin=-3,ymax=3)
# Out:
# -2
# 2
# Graphics object consisting of 6 graphics primitives

# %%
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=s*(s-1)*(s-2)
eq=solve(f(s)==0,s)
eq
x1=eq[0].rhs()
x2=eq[1].rhs()
x3=eq[2].rhs()
show(diff(f,s)(x1))
show(diff(f,s)(x2))
show(diff(f,s)(x3))
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3), headaxislength=3, headlength=4, color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq,x,[0,-0.5],step=0.01, end_points=[-5,5],output='plot', color='purple')
g2=desolve_rk4(deq,x,[0,1],step=0.01, end_points=[-5,5],output='plot', color='blue')
g3=desolve_rk4(deq,x,[0,2],step=0.01, end_points=[-5,5],output='plot', color='green')
g4=desolve_rk4(deq,x,[0,2.5],step=0.01, end_points=[-5,5],output='plot', color='orange')
g5=desolve_rk4(deq,x,[0,0.5],step=0.01, end_points=[-5,5],output='plot', color='black')
g6=desolve_rk4(deq,x,[0,1.5],step=0.01, end_points=[-5,5],output='plot', color='brown')
g=sf+g1+g2+g3+g4+g5+g6
g.show(ymin=-3,ymax=3)
# Out:
# 2
# -1
# 2
# Graphics object consisting of 7 graphics primitives

# %%
reset()
t,s=var('t,s')
x=function('x')(t)
f=function('f')(s)
f(s)=sin(s)
eq=solve(f(s)==0,s,to_poly_solve='force')
# Out:
# [s == pi*z2030]

# %%
xk(z2030)=eq[0].rhs()
xk
# Out:
# z2030 |--> pi*z2030

# %%
deq=diff(f,s)(xk(k))
g1=desolve_rk4(deq,x,[0,-0.5],step=0.01, end_points=[-5,5],output='plot', color='yellow')
g2=desolve_rk4(deq,x,[0,1],step=0.01, end_points=[-5,5],output='plot', color='blue')
g3=desolve_rk4(deq,x,[0,3],step=0.01, end_points=[-5,5],output='plot', color='green')
g4=desolve_rk4(deq,x,[0,2],step=0.01, end_points=[-5,5],output='plot', color='purple')
g5=desolve_rk4(deq,x,[0,0],step=0.01, end_points=[-5,5],output='plot', color='brown')
g=sf+g1+g2+g3+g4+g5
g.show(ymin=-3,ymax=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a3ec86c629ac> in <module>
# ----> 1 deq=diff(f,s)(xk(k))
#       2 g1=desolve_rk4(deq,x,[Integer(0),-RealNumber('0.5')],step=RealNumber('0.01'), end_points=[-Integer(5),Integer(5)],output='plot', color='yellow')
#       3 g2=desolve_rk4(deq,x,[Integer(0),Integer(1)],step=RealNumber('0.01'), end_points=[-Integer(5),Integer(5)],output='plot', color='blue')
#       4 g3=desolve_rk4(deq,x,[Integer(0),Integer(3)],step=RealNumber('0.01'), end_points=[-Integer(5),Integer(5)],output='plot', color='green')
#       5 g4=desolve_rk4(deq,x,[Integer(0),Integer(2)],step=RealNumber('0.01'), end_points=[-Integer(5),Integer(5)],output='plot', color='purple')
#
# NameError: name 'f' is not defined
